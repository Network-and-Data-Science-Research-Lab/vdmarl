# %%
from vdmarl.algorithms import QmixConfig
from vdmarl.environments import VmasTask
from vdmarl.experiment import Experiment, ExperimentConfig
from vdmarl.models.mlp import MlpConfig
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from vdmarl.algorithms import QmixConfig
#       2 from vdmarl.environments import VmasTask
#       3 from vdmarl.experiment import Experiment, ExperimentConfig
#
# File ~/projects/vdmarl/src/vdmarl/__init__.py:5
#       1 __version__ = "1.5.2"
#       3 import importlib
# ----> 5 import vdmarl.algorithms
#       6 import vdmarl.benchmark
#       7 import vdmarl.environments
#
# File ~/projects/vdmarl/src/vdmarl/algorithms/__init__.py:1
# ----> 1 from .common import Algorithm, AlgorithmConfig
#       2 from .ensemble import EnsembleAlgorithm, EnsembleAlgorithmConfig
#       3 from .avdnet import Avdnet, AvdnetConfig
#
# File ~/projects/vdmarl/src/vdmarl/algorithms/common.py:7
#       4 from dataclasses import dataclass
#       5 from typing import Any, Callable, Dict, Iterable, List, Optional, Tuple, Type
# ----> 7 from tensordict import TensorDictBase
#       8 from tensordict.nn import TensorDictModule, TensorDictSequential
#       9 from torchrl.data import (
#      10     Categorical,
#      11     LazyMemmapStorage,
#    (...)
#      15     TensorDictReplayBuffer,
#      16 )
#
# File ~/projects/vdmarl/.venv/lib/python3.10/site-packages/tensordict/__init__.py:6
#       1 # Copyright (c) Meta Platforms, Inc. and affiliates.
#       2 #
#       3 # This source code is licensed under the MIT license found in the
#       4 # LICENSE file in the root directory of this source tree.
# ----> 6 import tensordict._reductions
#       7 from tensordict._lazy import LazyStackedTensorDict
#       8 from tensordict._nestedkey import NestedKey
#
# File ~/projects/vdmarl/.venv/lib/python3.10/site-packages/tensordict/_reductions.py:10
#       7 import copyreg
#       8 from multiprocessing import reduction
# ---> 10 import torch
#      11 from tensordict._lazy import LazyStackedTensorDict
#      12 from tensordict._td import TensorDict
#
# File ~/projects/vdmarl/.venv/lib/python3.10/site-packages/torch/__init__.py:367
#     365     if USE_GLOBAL_DEPS:
#     366         _load_global_deps()
# --> 367     from torch._C import *  # noqa: F403
#     370 class SymInt:
#     371     """
#     372     Like an int (including magic methods), but redirects all operations on the
#     373     wrapped node. This is used in particular to symbolically record operations
#     374     in the symbolic shape workflow.
#     375     """
#
# ImportError: libcudnn.so.9: cannot open shared object file: No such file or directory

# %%
experiment_config = ExperimentConfig.get_from_yaml()
task = VmasTask.BALANCE.get_from_yaml()
algorithm_config = QmixConfig.get_from_yaml()
model_config = MlpConfig.get_from_yaml()
critic_model_config = MlpConfig.get_from_yaml()

experiment_config.max_n_frames = 12_000
experiment_config.loggers = []

# %%
experiment = Experiment(
    task=task,
    algorithm_config=algorithm_config,
    model_config=model_config,
    critic_model_config=critic_model_config,
    seed=0,
    config=experiment_config,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 experiment = Experiment(
#       2     task=task,
#       3     algorithm_config=algorithm_config,
#       4     model_config=model_config,
#       5     critic_model_config=critic_model_config,
#       6     seed=0,
#       7     config=experiment_config,
#       8 )
#
# File ~/projects/vdmarl/src/vdmarl/experiment/experiment.py:360, in Experiment.__init__(self, task, algorithm_config, model_config, seed, config, critic_model_config, callbacks)
#     357 self.algorithm_config = algorithm_config
#     358 self.seed = seed
# --> 360 self._setup()
#     362 self.total_time = 0
#     363 self.total_frames = 0
#
# File ~/projects/vdmarl/src/vdmarl/experiment/experiment.py:380, in Experiment._setup(self)
#     378 self._perform_checks()
#     379 self._set_action_type()
# --> 380 self._setup_name()
#     381 self._setup_task()
#     382 self._setup_algorithm()
#
# File ~/projects/vdmarl/src/vdmarl/experiment/experiment.py:567, in Experiment._setup_name(self)
#     561         save_folder = Path(
#     562             self.config.restore_file
#     563         ).parent.parent.parent.resolve()
#     564     # Otherwise, the user is not restoring and did not specify a save_folder so we save in the hydra directory
#     565     # of the experiment or in the directory where the experiment was run (if hydra is not used)
#     566     else:
# --> 567         save_folder = Path(HydraConfig.get().runtime.output_dir)
#     569 if self.config.restore_file is None:
#     570     self.name = generate_exp_name(
#     571         f"{self.algorithm_name}_{self.task_name}_{self.model_name}", ""
#     572     )
#
# File ~/projects/vdmarl/.venv/lib/python3.10/site-packages/hydra/core/hydra_config.py:31, in HydraConfig.get()
#      29 instance = HydraConfig.instance()
#      30 if instance.cfg is None:
# ---> 31     raise ValueError("HydraConfig was not set")
#      32 return instance.cfg.hydra
#
# ValueError: HydraConfig was not set

# %%
experiment.run()
